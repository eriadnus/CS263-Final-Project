# %%
import pandas as pd

df = pd.read_csv("TweetsNBA.csv", index_col=0)
df
# Out:
#                                                     text  retweet_count  \
# 1      RT @cavs: #NBAFinals GAME 3 STARTERS:\r\n\r\n@...              0
# 2      Ja comecou e eu no onibus  https://t.co/wPgRLw...              0
# 3        lets go Cavs\r\n#WhateverItTakes \r\n#NBAFinals              0
# 4      RT @cavs: #NBAFinals GAME 3 STARTERS:\r\n\r\n@...              0
# 5      RT @NBA:  Count down @StephenCurry30's TOP 5 t...              0
# ...                                                  ...            ...
# 51421  RT @NBAUK: Jordan Bell lifts off! ??\r\n\r\n#D...              0
# 51422  RT @OfficialNBARefs: What is it like to watch ...              0
# 51423  RT @fanaticsview:  LeBron James throws the bac...              0
# 51424                            https://t.co/mrT5JMngl4              0
# 51425  RT @NBA:  OH YES HE DID! \r\n\r\n#WhateverItTa...              0
#
#        favorite_count  favorited  truncated               id_str  \
# ...

# %%
df.iloc[0]
# Out:
# text                         RT @cavs: #NBAFinals GAME 3 STARTERS:\r\n\r\n@...
# retweet_count                                                                0
# favorite_count                                                               0
# favorited                                                                False
# truncated                                                                False
# id_str                                                     1004531741216989191
# in_reply_to_screen_name                                                    NaN
# source                       <a href="http://twitter.com/download/iphone" r...
# retweeted                                                                False
# created_at                                      Thu Jun 07 01:13:25 +0000 2018
# in_reply_to_status_id_str                                                  NaN
# in_reply_to_user_id_str                                                    NaN
# ...

# %%
df.iloc[0]['text']
# Out:
# "RT @cavs: #NBAFinals GAME 3 STARTERS:\r\n\r\n@George_Hill3\r\n@TheRealJRSmith\r\n@KingJames\r\n@kevinlove\r\n@RealTristan13\r\n\r\nLET'S GET IT. #WhateverItTakes h."

# %%
df.iloc[0]['text']
